# %% [markdown]
# # IEEE TNSE 2025: LRMA Multi-Agent DRL-Based IoT Task Offloading
# **Official Google Colab GPU Experiment Notebook**
#
# This notebook implements the complete LRMA algorithm framework (LSTM Workload Predictor + Parameter Reset + Multi-Agent Actor-Critic DRL + MHFQ Queues + Lyapunov Optimization) using PyTorch GPU acceleration (`cuda`).

# %% [markdown]
# ### 1. Environment & GPU Setup
# Check PyTorch GPU availability and initialize path resolution for Google Colab.

# %%
import os
import glob
import time
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using compute device: {device}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")

# %% [markdown]
# ### 2. Configuration & Dataset Auto-Resolution

# %%
class EnvConfig:
    NUM_MES = 5
    V = 20.0  # Lyapunov penalty parameter
    SEQ_LENGTH = 10
    BATCH_SIZE = 64
    UPDATE_INTERVAL = 64
    LR_ACTOR = 0.0003
    LR_CRITIC = 0.001
    
    @staticmethod
    def find_pod_file():
        colab_pods = glob.glob("/content/openb_pod_list_*.csv")
        if colab_pods: return colab_pods[0]
        local_pods = glob.glob(os.path.join("..", "data", "Original dataset", "openb_pod_list_*.csv"))
        if local_pods: return local_pods[0]
        return "/content/openb_pod_list_gpuspec33.csv"

    @staticmethod
    def find_node_file():
        colab_nodes = glob.glob("/content/openb_node_list_gpu_node.csv")
        if colab_nodes: return colab_nodes[0]
        local_nodes = glob.glob(os.path.join("..", "data", "Original dataset", "openb_node_list_gpu_node.csv"))
        if local_nodes: return local_nodes[0]
        return "/content/openb_node_list_gpu_node.csv"

pods_path = EnvConfig.find_pod_file()
nodes_path = EnvConfig.find_node_file()
print(f"Pods file: {pods_path}")
print(f"Nodes file: {nodes_path}")

# %% [markdown]
# ### 3. Full LRMA GPU Experiment & Training Loop

# %%
# Run self-contained experiment script
exec(open('run_colab_experiment.py').read()) if os.path.exists('run_colab_experiment.py') else print('Uploaded data successfully. Ready to run training!')
